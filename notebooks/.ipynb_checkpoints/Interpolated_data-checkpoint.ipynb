# %%
import numpy as np
import pyfits
import math
from math import log10
import matplotlib.pyplot as plt
import scipy
from scipy.stats import binned_statistic
from scipy.stats import binned_statistic_2d
from matplotlib import rc
import pickle
import os
import astropy as ap
from astropy.cosmology import WMAP7
os.chdir('/Users/nitya/Documents/new_data')
from scipy import interpolate


file_alpha = open(r'SFRP_edge_corrected.pkl', 'rb')
d = pickle.load(file_alpha,encoding ='latin1')
file_alpha.close()

file_beta = open(r'tracer_bin_magphys.pkl', 'rb')
a = pickle.load(file_beta,encoding ='latin1')
file_beta.close()

file_gamma = open(r'tracer_bin_opt_inf.pkl', 'rb')
b = pickle.load(file_gamma,encoding ='latin1')
file_gamma.close()

# %%
#Calculating UV SFR's



def jansky(flux,kcorrect):
    flux_in_Jy = flux*3631*(10.0**(-9.0))*(10**(kcorrect/(-2.5)))
    return flux_in_Jy


#Inverse Variance in Fluxes: (Input Flux inverse variance in Nmgy^-2)
def jansky_err(flux,kcorrect):
    Jy_err = (flux**(-0.5))*3631*(10.0**(-9.0))*(10**(kcorrect/(-2.5)))
    return Jy_err

def uvsfr(id,z,fmag,nmag,rmag,f_flux):
    fn = fmag - nmag
    opt = nmag - rmag   # N-r
    
    #Luminosity Distance
    dist = WMAP7.comoving_distance(z).value
    ldist = (1+z)*dist
    
    #calculating Attenuation 'a'
    if opt>=4.0:
        if fn < 0.95:
            a = 3.32*float(fn) + 0.22
        else:
            a = 3.37
    else:
        if fn < 0.90:
            a = 2.99*float(fn) +0.27
        else:
            a = 2.96

    lum = 4*3.14159*(ldist**2.0)*(3.087**2.0)*(10**(25.0 +(a/2.5)))*f_flux  #Luminosity
    sfr = 1.08*(10**(-28.0))*abs(lum)
    return sfr

# %%
# n_flux = jansky(d['NMGY'][:,1], d['KCORRECT'][:,1])
fmag = d['ABSMAG'][:,0]
nmag = d['ABSMAG'][:,1]
rmag = d['ABSMAG'][:,4]
z = d['Z']
ind = d['NSAID']
f_flux = [jansky(d['NMGY'][:,0][i], d['KCORRECT'][:,0][i]) for i in range(len(z))]
uvs = np.asarray([uvsfr(ind[i],z[i],fmag[i],nmag[i],rmag[i],f_flux[i]) for i in range(len(z))])

uv = np.log10(uvs)
lm = np.log10(d['MASS'])
uvssfr = np.asarray([np.log10(uvs[i] /d['MASS'][i]) for i in range(len(z))])
print(np.shape(d), np.shape(uvssfr))
# Out:
# (61084,) (61084,)

# %%
nsa = np.asarray(d['NSAID'])
opt = np.asarray([d['ABSMAG'][:,1][i] - d['ABSMAG'][:,4][i] for i in range(len(d['NSAID']))])
inf = np.asarray([d['W1MAG'][i] - d['W3MAG'][i] for i in range(len(d['NSAID']))])

points1 = np.column_stack((b[:,1],b[:,2]))
points2 = np.column_stack((opt,inf))
sfr = interpolate.griddata(points1,a[:,1],points2, method = 'linear')

print(sfr[0:10])
# Out:
# [-10.21664983 -10.3440649   -9.91430983 -10.6823062  -13.28396563
#  -10.05871764  -9.93409593 -10.27000432 -13.41983492 -13.4183362 ]

# %%
print(len(sfr))
indz = np.isnan(sfr)
print(len(sfr[indz]))
inds = np.invert(indz)
print(len(sfr[inds]))

mass = d['MASS'][inds]
magphys = sfr[inds]
print(mass[0:10])
uvssfr = uvssfr[inds]
lm = np.log10(mass)
uvsfr = np.asarray([lm[i] + uvssfr[i] for i in range(len(magphys))])
opt = opt[inds]
inf = inf[inds]
nsaid = d['NSAID'][inds]
# Out:
# 61084
# 38
# 61046
# [  1.70285722e+10   2.12651776e+09   6.05692928e+09   7.25714995e+09
#    6.35407718e+09   1.15024220e+10   9.07874918e+09   3.01139302e+09
#    1.37645650e+10   2.25363026e+10]

# %%
weird = np.where(uvssfr<=-15.0)[0]
print(len(nsaid[weird]))

w = np.where(uvssfr>=-14.0)[0]
print(len(nsaid[weird]))
z = z[inds]
# Out:
# 115
# 115

# %%
file_gamma = open(r'nsaid_env.pkl', 'rb')
e = pickle.load(file_gamma,encoding ='latin1')
file_gamma.close()

eid = np.asarray(e[:,0])
#let's remove the ones that are not in the edge corrected SFRP sample;
index0 = np.in1d(eid,nsaid)
print(len(eid[index0]))

env = np.asarray(e[:,1][index0])
# Out:
# 61046

# %%
cs = plt.scatter(inf,opt, c = magphys, cmap = plt.cm.Spectral, s = 10)
plt.colorbar()
plt.xlim(-3,3)
plt.ylim(0,7.5)
plt.show()

plt.scatter(inf,opt, c = uvssfr, cmap = plt.cm.Spectral, s = 10)
plt.colorbar(cs)
plt.xlim(-3,3)
plt.ylim(0,7.5)
plt.show()

plt.scatter(magphys, uvssfr, c = np.log10(env), cmap = plt.cm.Spectral_r, s=10)
plt.colorbar()
plt.show()

# %%
#Make a file with interpolated data: nsaid, z,opt,inf,lm,magphys_ssfr, uvsfr, uvssfr, environment: 0.5Mpcby1000km/s

whoa = np.array(np.column_stack((nsaid,z,opt,inf,lm,magphys,uvsfr,uvssfr,env)), dtype=[('nsaid',float), ('z',float),('opt',float),('inf',float), ('mass',float), ('magphys',float), ('uv',float), ('uvssfr',float), ('env', float)])

print(whoa.dtype.names)

# afile = open(r'interpolated_data.pkl', 'wb')
# pickle.dump(whoa, afile)
# afile.close()
# Out:
# ('nsaid', 'z', 'opt', 'inf', 'mass', 'magphys', 'uv', 'uvssfr', 'env')

# %%
#Making a binned_data file...:

t = binned_statistic_2d(inf,opt,ind,statistic = 'count',bins = (25,25))

yedges = t[1]
xedges = t[2]
xbins = [0.5*(t[1][i] + t[1][i+1]) for i in range(25)]
ybins = [0.5*(t[2][i] + t[2][i+1]) for i in range(25)]
extent = [xbins[0], xbins[-1], ybins[0], ybins[-1]]

number = np.ma.array(t[0], mask = t[0] == 0)
number = np.log10(number)

plt.pcolormesh(yedges,xedges,(np.transpose(number)),cmap = plt.cm.binary)
plt.colorbar()
# plt.xlim(0,0.056)
# plt.ylim(min(gr),max(gr))
plt.ylim(0,8.0)
plt.xlim(-3.0,3.0)
plt.xlabel('W1-W3')
plt.ylabel('N-r')
plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log10
#   if sys.path[0] == '':

# %%
b = np.reshape(np.asarray(t[3]),(len(nsaid),1))
bins = np.unique(t[3])
new = np.column_stack((b,opt,inf,mass,lm,magphys,uvsfr,uvssfr,env))
print(new[0:2])

new = new[new[:,0].argsort()]
n1 = [np.where(new[:,0] == bins[i]) for i in range(len(bins))]
print(new[0:2])
new1 =  np.array([np.mean(new[n1[i]], axis = 0) for i in range(len(bins))])
print(np.shape(new1))
print(new1[0:2])
# Out:
# [[  5.51000000e+02   3.20956802e+00   1.61400127e+00   1.70285722e+10
#     1.02311783e+01  -1.02166498e+01   4.41372987e-01  -9.78980530e+00
#     1.00000000e+00]
#  [  5.24000000e+02   3.08679771e+00   1.31699944e+00   2.12651776e+09
#     9.32766914e+00  -1.03440649e+01  -1.87904968e-01  -9.51557411e+00
#     1.00000000e+00]]
# [[  4.50000000e+01   5.14066601e+00  -2.90999985e+00   3.47769856e+09
#     9.54129219e+00  -1.18601209e+01  -1.24470497e+00  -1.07859972e+01
#     1.00000000e+00]
#  [  4.50000000e+01   5.10627365e+00  -2.89000130e+00   5.77099930e+09
#     9.76125145e+00  -1.21271010e+01  -6.21990381e-01  -1.03832418e+01
#     2.00000000e+00]]
# (444, 9)
# [[  4.50000000e+01   5.12346983e+00  -2.90000057e+00   4.62434893e+09
#     9.65127182e+00  -1.19936109e+01  -9.33347675e-01  -1.05846195e+01
#     1.50000000e+00]
#  [  4.90000000e+01   6.40465832e+00  -2.87550068e+00   1.06226573e+10
#     1.00052328e+01  -1.28710299e+01  -1.03979836e+00  -1.10450312e+01
#     2.00000000e+00]]

# %%
#let's list the NSAID's for each of these bins, along with the "counts"
b = np.reshape(np.asarray(t[3]),(len(nsaid),1))
bins = np.unique(t[3])
li = np.column_stack((b,nsaid))
# print(new[0:2])

li = li[li[:,0].argsort()]
n1 = [np.where(li[:,0] == bins[i]) for i in range(len(bins))]
# print(li[0:2])

idlist = np.asarray([li[:,1][n1[i]] for i in range(len(bins))])

# print(idlist[0:10])

counts = np.asarray([len(li[:,1][n1[i]]) for i in range(len(bins))])


stuff = np.asarray(np.column_stack((new1,counts)))
stuff2 = np.column_stack((new1[:,0],counts,idlist))



# afile = open(r'binned_counts_idlist.pkl', 'wb')
# pickle.dump(stuff2, afile)
# afile.close()


print(stuff[0:2])
print (np.shape(stuff))
# Out:
# [[  4.50000000e+01   5.12346983e+00  -2.90000057e+00   4.62434893e+09
#     9.65127182e+00  -1.19936109e+01  -9.33347675e-01  -1.05846195e+01
#     1.50000000e+00   2.00000000e+00]
#  [  4.90000000e+01   6.40465832e+00  -2.87550068e+00   1.06226573e+10
#     1.00052328e+01  -1.28710299e+01  -1.03979836e+00  -1.10450312e+01
#     2.00000000e+00   2.00000000e+00]]
# (444, 10)

# %%
stuff = (np.array(stuff,dtype=[('bin','f8'),('opt','f8'),('inf',float), ('mass',float), 
                               ('logmass', float),('magphys',float), ('uvsfr',float), 
                               ('uv',float), ('env', float), ('counts', float)]) )

# afile = open(r'binned_data.pkl', 'wb')
# pickle.dump(stuff, afile)
# afile.close()

print(stuff[0:2])
print(np.shape(stuff))
# Out:
# [[ (  4.50000000e+01,   4.50000000e+01,   4.50000000e+01,   4.50000000e+01,   4.50000000e+01,   4.50000000e+01,   4.50000000e+01,   4.50000000e+01,   4.50000000e+01,   4.50000000e+01)
#   (  5.12346983e+00,   5.12346983e+00,   5.12346983e+00,   5.12346983e+00,   5.12346983e+00,   5.12346983e+00,   5.12346983e+00,   5.12346983e+00,   5.12346983e+00,   5.12346983e+00)
#   ( -2.90000057e+00,  -2.90000057e+00,  -2.90000057e+00,  -2.90000057e+00,  -2.90000057e+00,  -2.90000057e+00,  -2.90000057e+00,  -2.90000057e+00,  -2.90000057e+00,  -2.90000057e+00)
#   (  4.62434893e+09,   4.62434893e+09,   4.62434893e+09,   4.62434893e+09,   4.62434893e+09,   4.62434893e+09,   4.62434893e+09,   4.62434893e+09,   4.62434893e+09,   4.62434893e+09)
#   (  9.65127182e+00,   9.65127182e+00,   9.65127182e+00,   9.65127182e+00,   9.65127182e+00,   9.65127182e+00,   9.65127182e+00,   9.65127182e+00,   9.65127182e+00,   9.65127182e+00)
#   ( -1.19936109e+01,  -1.19936109e+01,  -1.19936109e+01,  -1.19936109e+01,  -1.19936109e+01,  -1.19936109e+01,  -1.19936109e+01,  -1.19936109e+01,  -1.19936109e+01,  -1.19936109e+01)
#   ( -9.33347675e-01,  -9.33347675e-01,  -9.33347675e-01,  -9.33347675e-01,  -9.33347675e-01,  -9.33347675e-01,  -9.33347675e-01,  -9.33347675e-01,  -9.33347675e-01,  -9.33347675e-01)
#   ( -1.05846195e+01,  -1.05846195e+01,  -1.05846195e+01,  -1.05846195e+01,  -1.05846195e+01,  -1.05846195e+01,  -1.05846195e+01,  -1.05846195e+01,  -1.05846195e+01,  -1.05846195e+01)
#   (  1.50000000e+00,   1.50000000e+00,   1.50000000e+00,   1.50000000e+00,   1.50000000e+00,   1.50000000e+00,   1.50000000e+00,   1.50000000e+00,   1.50000000e+00,   1.50000000e+00)
#   (  2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00)]
#  [ (  4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01,   4.90000000e+01)
#   (  6.40465832e+00,   6.40465832e+00,   6.40465832e+00,   6.40465832e+00,   6.40465832e+00,   6.40465832e+00,   6.40465832e+00,   6.40465832e+00,   6.40465832e+00,   6.40465832e+00)
#   ( -2.87550068e+00,  -2.87550068e+00,  -2.87550068e+00,  -2.87550068e+00,  -2.87550068e+00,  -2.87550068e+00,  -2.87550068e+00,  -2.87550068e+00,  -2.87550068e+00,  -2.87550068e+00)
#   (  1.06226573e+10,   1.06226573e+10,   1.06226573e+10,   1.06226573e+10,   1.06226573e+10,   1.06226573e+10,   1.06226573e+10,   1.06226573e+10,   1.06226573e+10,   1.06226573e+10)
#   (  1.00052328e+01,   1.00052328e+01,   1.00052328e+01,   1.00052328e+01,   1.00052328e+01,   1.00052328e+01,   1.00052328e+01,   1.00052328e+01,   1.00052328e+01,   1.00052328e+01)
#   ( -1.28710299e+01,  -1.28710299e+01,  -1.28710299e+01,  -1.28710299e+01,  -1.28710299e+01,  -1.28710299e+01,  -1.28710299e+01,  -1.28710299e+01,  -1.28710299e+01,  -1.28710299e+01)
#   ( -1.03979836e+00,  -1.03979836e+00,  -1.03979836e+00,  -1.03979836e+00,  -1.03979836e+00,  -1.03979836e+00,  -1.03979836e+00,  -1.03979836e+00,  -1.03979836e+00,  -1.03979836e+00)
#   ( -1.10450312e+01,  -1.10450312e+01,  -1.10450312e+01,  -1.10450312e+01,  -1.10450312e+01,  -1.10450312e+01,  -1.10450312e+01,  -1.10450312e+01,  -1.10450312e+01,  -1.10450312e+01)
#   (  2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00)
#   (  2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00,   2.00000000e+00)]]
# (444, 10)

# %%
def scontour(x,y,n):
    try:
        from astropy.convolution import Gaussian2DKernel, convolve
        astro_smooth = True
    except ImportError as IE:
        astro_smooth = False

    H, xedges, yedges = np.histogram2d(x,y, bins=(np.int(n),np.int(n)))
    xmesh, ymesh = np.meshgrid(xedges[:-1], yedges[:-1])

    # Smooth the contours (if astropy is installed)
    if astro_smooth:
        kernel = Gaussian2DKernel(stddev=1.)
        H=convolve(H,kernel)

    fig,ax = plt.subplots(1, figsize=(7,6)) 
    clevels = ax.contour(xmesh,ymesh,H.T, lw = 40)#,zorder=90)
    #ax.clabel(clevels)

    # Identify points within contours
    p = clevels.collections[0].get_paths()
    inside = np.full_like(x,False,dtype=bool)
    for level in p:
        inside |= level.contains_points(list(zip(*(x,y))))

    ax.scatter(x[~inside],y[~inside],s = 10)
    plt.colorbar(clevels)
    plt.show(block=False)

    
scontour(inf,opt,10)

scontour(magphys,uvssfr, 20)
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'lw'
#   s)
