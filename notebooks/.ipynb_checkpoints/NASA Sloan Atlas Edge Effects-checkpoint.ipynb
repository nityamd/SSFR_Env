# %%
# %matplotlib inline
import numpy as np
import pyfits
import math
import matplotlib.pyplot as plt
import scipy
import scipy.spatial as ss
from scipy.stats import binned_statistic
from scipy.stats import binned_statistic_2d
from matplotlib import rc
import pickle
import os
import astropy as ap
from astropy.cosmology import WMAP7
from pylab import *
from matplotlib.path import Path
import matplotlib.patches as patches
import seaborn as sns
import sys 

#rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('font',**{'family':'serif','serif':['Times'], 'size': 15})
rc('text', usetex=True)      

SMALL_SIZE = 13
MEDIUM_SIZE = 15
BIGGER_SIZE = 17

plt.rc('font', size=SMALL_SIZE) 
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)

os.chdir('/Users/nitya/Work/Data/Project1/edge_effects')
print(os.getcwd())

d = pyfits.open("lss_combmask.dr72.fits")
d = d[1].data
print(d.columns)
fg= d['fgotmain']
ind0 = np.where(fg==0)[0]
ind1 = np.where(fg==1.0)[0]
print(len(fg[ind0]), len(fg[ind1]))
# Out:
# /Users/nitya/Documents/edge_effects
# ColDefs(
#     name = 'XCAPS'; format = '42D'; dim = '( 3, 14)'
#     name = 'CMCAPS'; format = '14D'
#     name = 'NCAPS'; format = 'J'
#     name = 'WEIGHT'; format = 'D'
#     name = 'STR'; format = 'D'
#     name = 'USE_CAPS'; format = 'J'; bscale = 1; bzero = 2147483648
#     name = 'RA'; format = 'D'
#     name = 'DEC'; format = 'D'
#     name = 'SECTOR'; format = 'J'
#     name = 'MMAX'; format = 'E'
#     name = 'DIFFRUN'; format = 'J'
#     name = 'ITILING_GEOMETRY'; format = 'J'
#     name = 'ITARGET_GEOMETRY'; format = 'J'
#     name = 'ILSS'; format = 'J'
#     name = 'FGOTMAIN'; format = 'E'
# )
# 6803 66656

# %%
os.chdir('/Users/nitya/Work/Data/Project1/measurements')
print(os.getcwd())

file2 = open(r'SFRP.pkl','rb')
d2 = pickle.load(file2, encoding ='latin1')
file2.close()

file3 = open(r'EDP.pkl','rb')
d3 = pickle.load(file3, encoding ='latin1')
file3.close()
# Out:
# /Users/nitya/Documents/new_data

# %%
ra = np.asarray(d2['RA'])
dec = np.asarray(d2['DEC'])
nsa = np.asarray(d2['NSAID'])
plt.scatter(ra,dec, s = 0.01)
plt.xlabel('RA')
plt.ylabel('DEC')
plt.title('Original SFRP')
plt.show()


ra2 = np.asarray(d3['RA'])
dec2 = np.asarray(d3['DEC'])
nsa2 = np.asarray(d3['NSAID'])
plt.scatter(ra2,dec2, s = 0.01)
plt.xlabel('RA')
plt.ylabel('DEC')
plt.title('Original EDP')
plt.show()

# %%
#SFR RA Dec file
# stuff1 = np.column_stack((ra,dec))
# filename = 'sfr_ra_dec'
# f = open(filename,'w')
# for line in stuff1:
#     f.write("  ".join(str(x) for x in line) + "\n")
# f.close()

# #EDP RA Dec File
# stuff2 = np.column_stack((ra2,dec2))
# filename = 'edp_ra_dec'
# f = open(filename,'w')
# for line in stuff2:
#     f.write("  ".join(str(x) for x in line) + "\n")
# f.close()

# %% [markdown]
# 1. The combmask polygon file was pixelized and snapped and polyid.sh was run to determine whether or not said galaxy (within EDP/SFRP) was within one of these polygons.
# 2. Effectively this removed the SEGUE galaxies (among other things) and reduced our SFRP and EDP sizes to 62991 and 75476 respectively;
# 3. Setting fgotmain to > 0.8 leaves us with 62317 galaxies in SFRP and 77307 in EDP;

# %%
os.chdir('/Users/nitya/Documents/edge_effects')
print(os.getcwd())

w = open('sfr_polyid_0', 'r')
u = np.asarray(w.readlines())
print(u[0])

v = np.array([np.array(u[1:][i].split(), dtype = float) for i in range(len(u[1:]))])

rap = np.asarray([v[i][0] for i in range(len(v))])
decp = np.asarray([v[i][1] for i in range(len(v))])
lens = np.asarray([len(v[i]) for i in range(len(v))])

i1 = np.where(lens==3)[0]
i2 = np.where(lens==2)[0]
print(len(v))
print(len(v[i1]))
print(len(v[i2]))

#NEW SFRP
b2 = d2[i1]
afile = open(r'SFRTP.pkl', 'wb')
pickle.dump(b2, afile)
afile.close()

#polygons
p_sfr = np.asarray([v[i1][i][2] for i in range(len(v[i1]))])

#EDP stuff
f = open('edp_polyid_0', 'r')
g = np.asarray(f.readlines())
print(g[0])
h = np.array([np.array(g[1:][i].split(), dtype = float) for i in range(len(g[1:]))])

raq = np.asarray([h[i][0] for i in range(len(h))])
decq = np.asarray([h[i][1] for i in range(len(h))])
lens2 = np.asarray([len(h[i]) for i in range(len(h))])
print(lens2)

j1 = np.where(lens2==3)[0]
j2 = np.where(lens2==2)[0]
print(len(h))
print(len(h[j1]))
print(len(h[j2]))

b3 = d3[j1]
afile = open(r'ETP.pkl', 'wb')
pickle.dump(b3, afile)
afile.close()

#polygons
p_edp = np.asarray([h[j1][i][2] for i in range(len(h[j1]))])
# Out:
# /Users/nitya/Documents/edge_effects
#       az(d)       el(d) polygon_ids
#
# 75476
# 62991
# 12484
#       az(d)       el(d) polygon_ids
#
# [2 3 3 ..., 3 3 3]
# 95638
# 78174
# 17463

# %%
plt.scatter(rap[i1],decp[i1], s = 0.01, label = 'in combmask')
plt.scatter(rap[i2],decp[i2], s = 0.01, label = 'outside combmask')
plt.xlabel('RA')
plt.ylabel('Dec')
plt.title('SFRP')
plt.legend(loc = 1, markerscale = 30)
plt.savefig('new_sfrp.pdf')
plt.show()

plt.scatter(raq[j1],decq[j1], s = 0.01, label = 'in combmask')
plt.scatter(raq[j2],decq[j2], s = 0.01, label = 'outside combmask')
plt.xlabel('RA')
plt.ylabel('Dec')
plt.title('EDP')
lgnd = plt.legend(loc = 1, markerscale = 30)
plt.savefig('new_edp.pdf')
plt.show()

# %%
#Checking if the RA-Dec's match up;

indices = [np.int(p_edp[i]) for i in range(len(p_edp))]
# print(d['RA'][indices[0:10]],d['DEC'][indices[0:10]])
# print(raq[j1][0:10],decq[j1][0:10])
# print(fg[indices[0:10]])

indices2 = [np.int(p_sfr[i]) for i in range(len(p_sfr))]
# print(d['RA'][indices2[0:10]],d['DEC'][indices2[0:10]])
# print(rap[i1][0:10],decp[i1][0:10])
# print(fg[indices2[0:10]])

#Setting fgotmain's to > 0.8

good = np.where(fg[indices]> 0.8)[0]
odd = np.where(fg[indices]<=0.8)[0]


good2 = np.where(fg[indices2]>0.8)[0]
odd2 = np.where(fg[indices2]<=0.8)[0]

c2 = b2[good2]
c3 = b3[good]

print(len(c2),len(c3))
# Out:
# 62317 77307

# %%
#time to pickle EDP's, SFRP's with fgotmain>0.8

# afile = open(r'fg0.8_sfrp.pkl', 'wb')
# pickle.dump(c2, afile)
# afile.close()

# afile = open(r'fg0.8_edp.pkl', 'wb')
# pickle.dump(c3, afile)
# afile.close()

# %% [markdown]
# Galaxies at the Survey Edge: (Our sample, S has 77307 galaxies)
#
# 1. We first populate our polygons with N = 1,000,000 random galaxies; (So we have sample B of 1,000,000 points in this projected-2D-plane?)
#
# 2. For R_aperture/"transverse linking length" r, find out what the corresponding angular separation t is for each galaxy is S;
#
# 3. For each galaxy in S, we need to count number of galaxies in B within t and then look at the distribution of t and obviously the edges will pop out in the lower end;

# %% [markdown]
# Before going any further and defining this as our EDP for realz, let's set a lower bound for z...:

# %%
#Aperture size = 0.5 Mpc; c3: EDP array; 
r = 0.5
z = np.asarray(c3['Z'])

print(np.min(z),np.max(z),np.median(z))
low_z = np.where(z<=0.0015)[0]
sampl = np.where(z>0.0015)[0]
print(len(z[low_z]))

d3 = c3[sampl]


nsaid = np.asarray(c3['NSAID'][sampl])
ra = np.asarray(c3['RA'][sampl])
dec = np.asarray(c3['DEC'][sampl])
z = np.asarray(c3['Z'][sampl])

dist = np.array([WMAP7.comoving_distance(z[i]).value for i in range(len(z))])
#theta
t = np.asarray([r/dist[i] for i in range(len(dist))])
print(np.min(t),np.max(t))
# Out:
# -0.000269925 0.0550015 0.0424395
# 14
# 0.0021593187698 0.0698651423694

# %%
# %%time

# #Loading the Ransack RA, Dec's;

# os.chdir('/Users/nitya/Documents')
# w = open('ransacked_100M', 'r')
# u = np.asarray(w.readlines())
# #print(u[0:10])

# v = np.array([np.array(u[1:][i].split(), dtype = float) for i in range(len(u[1:]))])

# ra_r = np.asarray([v[i][0] for i in range(len(v))])
# dec_r = np.asarray([v[i][1] for i in range(len(v))])
# #polygons



#let's store the ransack Ra, Dec's and the polygons they fall in;

# rans = np.column_stack((ra_r,dec_r,p_r))

# afile = open(r'ransack10M_radecpolygon.pkl', 'wb')
# pickle.dump(rans, afile)
# afile.close()

# %%
# %%time
import pandas as pd

w = pd.read_csv('ransacked_100M', header = None, sep = '\t')
# Out:
# CPU times: user 1min 20s, sys: 11.8 s, total: 1min 32s
# Wall time: 1min 41s

# %%
ra_r = w.iloc[:,0].values
dec_r = w.iloc[:,1].values

# %%
# plt.scatter(ra_r,dec_r, s = 0.0001)
# plt.scatter(ra,dec, s= 0.001)
# plt.show()

# %%
# On a unit sphere:

# def coords(ra,dec):
#         radius = 1.0
        
#         x = radius*np.cos(dec*np.pi/180.0)*np.cos(ra*np.pi/180.0)
#         y = radius*np.cos(dec*np.pi/180.0)*np.sin(ra*np.pi/180.0)
#         zed = radius*np.sin(dec*np.pi/180.0)
#         return x,y,zed

# %%
# %%time

# x, y, zed = coords(ra_r,dec_r)

# %%
# co = np.column_stack((x,y,zed))

# filename = 'x_y_zed'
# f = open(filename,'w')
# for line in co:
#     f.write("  ".join(str(x) for x in line) + "\n")
# f.close()

# %%
# %%time

# points = np.column_stack((x,y,zed))
# tree = ss.KDTree(points)

# %% [markdown]
# So, here's the logic:
# 1 ==> comoving distance;
# s ==> 0.5 Mpc
#
# So I guess 's' here is my old angular aperture size theta (t[i]).. right?
#
# But you end up using the small angle approximation here for arc length ~ chord length..
# Meaning for larger theta's this is a problem....

# %%
# %%time

print(np.max(t),np.sin(np.max(t)))
print(np.median(t),np.sin(np.median(t)))
print(np.mean(t),np.sin(np.mean(t)))

# sample_x, sample_y, sample_z = coords(ra,dec)
# sample = np.column_stack((sample_x,sample_y, sample_z))
# ns = [tree.query_ball_point(sample[i],t[i]) for i in range(len(t))]
# print(len(ns))
# nc = np.asarray([len(ns[i]) for i in range(len(ns))])
# id_count = np.column_stack((nsaid,nc))

# afile = open(r'ransack100M_nsaid_count.pkl', 'wb')
# pickle.dump(id_count, afile)
# afile.close()
# Out:
# 0.0698651423694 0.0698083193376
# 0.00279076301621 0.00279075939364
# 0.0033859659778 0.00338595950792
# CPU times: user 5.25 ms, sys: 4.85 ms, total: 10.1 ms
# Wall time: 10.3 ms

# %%
os.chdir('/Users/nitya/Documents/new_data')
print(os.getcwd())

file4 = open(r'ransack100M_nsaid_count.pkl','rb')
k = pickle.load(file4, encoding ='latin1')
file4.close()

nc = np.asarray(k[:,1])
print(nc[0:10], np.min(nc), np.max(nc), np.mean(nc))

area = np.sum(d['STR'])
print(area)
fgot = fg[indices][good][sampl]
# Out:
# /Users/nitya/Documents/new_data
# [ 796  888 1393  620 1829  666 1855  653 1264 1359] 245 629427 2243.8162188
# 2.38158318918

# %% [markdown]
# Expected value of n: (from Hahn et al 2015)
#
# $$<n_{i}> = \frac{N_{r}}{A_{EDP}}\pi \theta_{i}^{2}f_{thresh}$$

# %%
n_exp = np.asarray([(100000000/area)*np.pi*(t[i]**2) for i in range(len(t))])
n_exp2 = np.asarray([(100000000/area)*np.pi*(t[i]**2) for i in range(len(t))])

#res = np.asarray([nc[i]-n_exp[i] for i in range(len(nc))])

index1 = np.where(nc>=10000)[0]
print(len(n_exp[index1]))
#print(n_exp[index1],n_r[index1])

index2 = np.where(nc>=10000)[0]
print(len(n_exp[index2]))
#print(n_exp[index2],n_r[index2])
# Out:
# 1165
# 1165

# %%
print('n_ransack,    n_exp*fg,    n_exp')
print('min',np.min(nc),',' ,np.min(n_exp2),',', np.min(n_exp))
print('max', np.max(nc), ',',np.max(n_exp2), ',',np.max(n_exp))
print('mean',np.mean(nc),',', np.mean(n_exp2), ',',np.mean(n_exp))
print('median',np.median(nc),',', np.median(n_exp2),',', np.median(n_exp))


plt.scatter(n_exp2,nc, s = 10)
plt.plot([0,500,10000],[0,500,10000], color ='r')
plt.xlim(0,10000)
plt.ylim(0,10000)
plt.xlabel(r'$<n_{i}>$')
plt.ylabel(r'$n_{ransack}$')
plt.show()


plt.scatter(n_exp2,nc, s = 10)
plt.plot([0,500,10000],[0,500,10000], color ='r')
plt.xlim(0,5000)
plt.ylim(0,5000)
plt.xlabel(r'$<n_{i}>$')
plt.ylabel(r'$n_{ransack}$')
plt.show()
# Out:
# n_ransack,    n_exp*fg,    n_exp
# min 245 , 615.060215851 , 615.060215851
# max 629427 , 643880.412125 , 643880.412125
# mean 2243.8162188 , 2319.67753167 , 2319.67753167
# median 1001.0 , 1027.37746284 , 1027.37746284

# %%
what = np.asarray([nc[i]/n_exp2[i] for i in range(len(nc))])

plt.scatter(nc,what, s= 10)
plt.xlabel(r'$n_{ransack}$')
#plt.xlim(0,100)
plt.show()

plt.scatter(nc,what, s = 10)
plt.xlim(0,10000)
plt.xlabel(r'$n_{ransack}$')
plt.show()


plt.scatter(nc,what, s= 0.5)
plt.xlim(0,5000)
plt.xlabel(r'$n_{ransack}$')
plt.plot([0,100,5000],[0.9,0.9,0.9], color = 'r')
plt.show()


plt.scatter(nc,what, s= 0.5)
plt.xlim(500,3000)
plt.xlabel(r'$n_{ransack}$')
plt.plot([0,100,5000],[0.9,0.9,0.9], color = 'r')
plt.show()

plt.scatter(nc,what, s= 0.5)
plt.xlim(1500,2500)
plt.xlabel(r'$n_{ransack}$')
plt.plot([0,100,5000],[0.9,0.9,0.9], color = 'r')
plt.show()

# %%
#Pick f_{thresh} to define the edges?

f_thresh = 0.8


thresh = np.where(nc >= f_thresh*n_exp2)[0]
below_thresh = np.where(nc <= f_thresh*n_exp2)[0]

e3 = d3[thresh]

print(np.shape(e3))
print(len(nc[thresh]))
print(len(nc[below_thresh]))
plt.scatter(ra[thresh],dec[thresh], s = 0.02, label = 'Not Edge')
plt.scatter(ra[below_thresh],dec[below_thresh], s = 0.2, label = 'Edge')
plt.xlabel('RA')
plt.ylabel('Dec')
plt.title('EDP')
lgnd = plt.legend(loc = 1, markerscale = 30)
plt.savefig('edge.pdf')
plt.show()

# afile = open(r'final_sample.pkl', 'wb')
# pickle.dump(e3, afile)
# afile.close()
# Out:
# (75744,)
# 75744
# 1549

# %%
id_env = e3['NSAID']
id_sfr = c2['NSAID']

print(len(id_env))
print(len(id_sfr))
imp = np.in1d(id_sfr,id_env)

print(len(id_sfr[imp]))

d2 = c2[imp]

afile = open(r'SFRP_edge_corrected.pkl', 'wb')
pickle.dump(d2, afile)
afile.close()
# Out:
# 75744
# 62317
# 61084

# %%
what = np.asarray([nc[i]/n_exp2[i] for i in range(len(nc))])

plt.scatter(n_exp2,what, s= 10)
plt.xlabel(r'$n_{exp}$')
#plt.xlim(0,100)
plt.show()

plt.scatter(n_exp2,what, s = 10)
plt.xlim(0,10000)
plt.xlabel(r'$n_{exp}$')
plt.show()


plt.scatter(n_exp2,what, s= 0.5)
plt.xlim(0,10000)
plt.xlabel(r'$n_{exp}$')
plt.plot([0,100,10000],[0.9,0.9,0.9], color = 'r')
plt.show()


plt.scatter(n_exp2,what, s= 0.5)
plt.xlim(0,2000)
plt.xlabel(r'$n_{exp}$')
plt.plot([0,100,2000],[0.9,0.9,0.9], color = 'r')
plt.show()

# %%
try:
    from astropy.convolution import Gaussian2DKernel, convolve
    astro_smooth = True
except ImportError as IE:
    astro_smooth = False

H, xedges, yedges = np.histogram2d(nc,what, bins=(25,25))
xmesh, ymesh = np.meshgrid(xedges[:-1], yedges[:-1])

# Smooth the contours (if astropy is installed)
if astro_smooth:
    kernel = Gaussian2DKernel(stddev=1.)
    H=convolve(H,kernel)

fig,ax = plt.subplots(1, figsize=(7,6)) 
clevels = ax.contour(xmesh,ymesh,H.T, lw = 40)#,zorder=90)
#ax.clabel(clevels)

# Identify points within contours
p = clevels.collections[0].get_paths()
inside = np.full_like(nc,False,dtype=bool)
for level in p:
    inside |= level.contains_points(list(zip(*(nc,what))))

ax.scatter(nc[~inside],what[~inside],s = 10)
plt.xlim(0,100000)
plt.colorbar(clevels)
plt.show(block=False)
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'lw'
#   s)
